# %%
#Shardul Rasal
#25070123155
#Aim:to study the python dictionaries
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year":1964

}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year":1964,
    "year":2000

}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2000}
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2000}

# %%
car = {
    "brand": "Ford",
    "model": "Mustang",
    "year":1964
}
car["color"] = "red"
print(type(car))
print(car)
x = car.values()
print(x) #after the change
# Out:
# <class 'dict'>
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}
# dict_values(['Ford', 'Mustang', 1964, 'red'])

# %%
student = {
    "roll":101,
    "name": "Amit",
    "branch":"ENTC"

}
print("name",student["name"])
student.pop("branch")
print(student)
# Out:
# name Amit
# {'roll': 101, 'name': 'Amit'}

# %%
products = {"pen": 10, "book": 50,"scale":20}
print("Original Product:",products)
products["books"] = 55
print("Updated Product:",products)


#
# Out:
# Original Product: {'pen': 10, 'book': 50, 'scale': 20}
# Updated Product: {'pen': 10, 'book': 50, 'scale': 20, 'books': 55}

# %%
marks = {"A":85,"B":72,"C":90}
name = input("Enter the name of the student:")
print(marks.get(name, "Student not Found"))
# Out:
# Enter the name of the student:D
# Student not Found

# %%
users={"admin":'1234',"student":"abcd"}
username = input("Enter the username:")
password = input("Enter the password:")

if username in users:
    if users[username] == password:
        print("Login Successful")
    else:
        print("Invalid Password")
else:
    print("Invalid Username")
# Out:
# Enter the username:abcd
# Enter the password:abcd
# Invalid Username

# %%
marks = {"A":85,"B":92,"C":78}
topper = max(marks, key=marks.get)
print("Topper:",topper)
print("Marks:",marks[topper])
# Out:
# Topper: B
# Marks: 92
